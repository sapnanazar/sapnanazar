# %% [markdown]
# NAME SAPNA NAZAR

# %% [markdown]
# ROLL NO 0162

# %% [markdown]
# ASSIGNMENT DATA PROCESSING WITH PANDAS

# %%
import pandas as pd

# %%
df=pd.read_csv("clothing.csv")

# %%
df
# Out:
#     Customer ID  Age Gender Item Purchased     Category  \
# 0             1   55   Male          Shirt     Clothing
# 1             2   19  Male\       Sweater.          NaN
# 2             3   50   Male         Jeans.     Clothing
# 3             4   21   Male        Sandals     Footwear
# 4             5   45   Male            NaN     Clothing
# ..          ...  ...    ...            ...          ...
# 95           96   37   Male       Sneakers     Footwear
# 96           97   32   Male         Gloves  Accessories
# 97           98   21   Male          Shoes     Footwear
# 98           99   20   Male          Jeans     Clothing
# 99          100   26  Male\            NaN     Clothing
#
#     Purchase Amount (USD) Size
# 0                      53    L
# 1                      64    L
# 2                      73    S
# 3                      10    M
# 4                      49    M
# ..                    ...  ...
# 95                     53    L
# 96                     53    S
# ...

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male          Shirt  Clothing                     53
# 1            2   19  Male\       Sweater.       NaN                     64
# 2            3   50   Male         Jeans.  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     10
# 4            5   45   Male            NaN  Clothing                     49
#
#   Size
# 0    L
# 1    L
# 2    S
# 3    M
# 4    M

# %%
df.drop_duplicates()
# Out:
#     Customer ID  Age Gender Item Purchased     Category  \
# 0             1   55   Male          Shirt     Clothing
# 1             2   19  Male\       Sweater.          NaN
# 2             3   50   Male         Jeans.     Clothing
# 3             4   21   Male        Sandals     Footwear
# 4             5   45   Male            NaN     Clothing
# ..          ...  ...    ...            ...          ...
# 95           96   37   Male       Sneakers     Footwear
# 96           97   32   Male         Gloves  Accessories
# 97           98   21   Male          Shoes     Footwear
# 98           99   20   Male          Jeans     Clothing
# 99          100   26  Male\            NaN     Clothing
#
#     Purchase Amount (USD) Size
# 0                      53    L
# 1                      64    L
# 2                      73    S
# 3                      10    M
# 4                      49    M
# ..                    ...  ...
# 95                     53    L
# 96                     53    S
# ...

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#     Customer ID  Age Gender Item Purchased     Category  \
# 0             1   55   Male          Shirt     Clothing
# 1             2   19  Male\       Sweater.          NaN
# 2             3   50   Male         Jeans.     Clothing
# 3             4   21   Male        Sandals     Footwear
# 4             5   45   Male            NaN     Clothing
# ..          ...  ...    ...            ...          ...
# 95           96   37   Male       Sneakers     Footwear
# 96           97   32   Male         Gloves  Accessories
# 97           98   21   Male          Shoes     Footwear
# 98           99   20   Male          Jeans     Clothing
# 99          100   26  Male\            NaN     Clothing
#
#     Purchase Amount (USD) Size
# 0                      53    L
# 1                      64    L
# 2                      73    S
# 3                      10    M
# 4                      49    M
# ..                    ...  ...
# 95                     53    L
# 96                     53    S
# ...

# %%
df["Gender"].str.lstrip (" / ")
df["Item Purchased"].str.lstrip(" ... ")
# Out:
# 0        Shirt
# 1     Sweater.
# 2       Jeans.
# 3      Sandals
# 4          NaN
#         ...
# 95    Sneakers
# 96      Gloves
# 97       Shoes
# 98       Jeans
# 99         NaN
# Name: Item Purchased, Length: 100, dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of     Customer ID  Age Gender Item Purchased     Category  \
# 0             1   55   Male          Shirt     Clothing
# 1             2   19  Male\       Sweater.          NaN
# 2             3   50   Male         Jeans.     Clothing
# 3             4   21   Male        Sandals     Footwear
# 4             5   45   Male            NaN     Clothing
# ..          ...  ...    ...            ...          ...
# 95           96   37   Male       Sneakers     Footwear
# 96           97   32   Male         Gloves  Accessories
# 97           98   21   Male          Shoes     Footwear
# 98           99   20   Male          Jeans     Clothing
# 99          100   26  Male\            NaN     Clothing
#
#     Purchase Amount (USD) Size
# 0                      53    L
# 1                      64    L
# 2                      73    S
# 3                      10    M
# 4                      49    M
# ..                    ...  ...
# 95                     53    L
# ...

# %%
df.nunique()
# Out:
# Customer ID              100
# Age                       46
# Gender                     2
# Item Purchased            31
# Category                   4
# Purchase Amount (USD)     13
# Size                       5
# dtype: int64

# %% [markdown]
# THANKS
